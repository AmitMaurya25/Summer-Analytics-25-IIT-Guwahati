# %% [markdown]
# <a href="https://colab.research.google.com/github/AmitMaurya25/Summer-Analytics-25-IIT-Guwahati/blob/main/Untitled34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
## import neccessary modules for working with data
import pandas as pd
# !pip install seaborn

import seaborn as sns
import numpy as np
from sklearn import set_config
set_config(display = 'diagram')
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv('/content/hacktrain.csv')
df1
# Out:
#       Unnamed: 0     ID       class  20150720_N  20150602_N  20150517_N  \
# 0              0      1       water    637.5950     658.668   -1882.030
# 1              1      2       water    634.2400     593.705   -1625.790
# 2              3      4       water     58.0174   -1599.160         NaN
# 3              4      5       water     72.5180         NaN     380.436
# 4              7      8       water   1136.4400         NaN         NaN
# ...          ...    ...         ...         ...         ...         ...
# 7995       10537  10538  impervious   1207.7000     984.620         NaN
# 7996       10538  10539  impervious   2170.3500    1419.720    1361.000
# 7997       10541  10542  impervious   1895.6800    1454.740         NaN
# 7998       10542  10543  impervious   3465.7400    1283.320     413.412
# 7999       10544  10545  impervious   6941.1900    1667.870    5084.780
#
#       20150501_N  20150415_N  20150330_N  20150314_N  ...  20140610_N  \
# ...

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'class', '20150720_N', '20150602_N', '20150517_N',
#        '20150501_N', '20150415_N', '20150330_N', '20150314_N', '20150226_N',
#        '20150210_N', '20150125_N', '20150109_N', '20141117_N', '20141101_N',
#        '20141016_N', '20140930_N', '20140813_N', '20140626_N', '20140610_N',
#        '20140525_N', '20140509_N', '20140423_N', '20140407_N', '20140322_N',
#        '20140218_N', '20140202_N', '20140117_N', '20140101_N'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0       0
# ID               0
# class            0
# 20150720_N     560
# 20150602_N    1200
# 20150517_N     800
# 20150501_N     960
# 20150415_N     480
# 20150330_N    1120
# 20150314_N     720
# 20150226_N    1360
# 20150210_N     640
# 20150125_N    1040
# 20150109_N     880
# 20141117_N    1280
# 20141101_N     400
# 20141016_N    1440
# 20140930_N     800
# 20140813_N     560
# 20140626_N    1600
# 20140610_N     480
# 20140525_N     720
# 20140509_N     880
# 20140423_N    1760
# 20140407_N     640
# 20140322_N    1120
# 20140218_N    1440
# 20140202_N     560
# 20140117_N    1200
# 20140101_N     400
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7995    False
# 7996    False
# 7997    False
# 7998    False
# 7999    False
# Length: 8000, dtype: bool

# %%
df1.dtypes
# Out:
# Unnamed: 0      int64
# ID              int64
# class          object
# 20150720_N    float64
# 20150602_N    float64
# 20150517_N    float64
# 20150501_N    float64
# 20150415_N    float64
# 20150330_N    float64
# 20150314_N    float64
# 20150226_N    float64
# 20150210_N    float64
# 20150125_N    float64
# 20150109_N    float64
# 20141117_N    float64
# 20141101_N    float64
# 20141016_N    float64
# 20140930_N    float64
# 20140813_N    float64
# 20140626_N    float64
# 20140610_N    float64
# 20140525_N    float64
# 20140509_N    float64
# 20140423_N    float64
# 20140407_N    float64
# 20140322_N    float64
# 20140218_N    float64
# 20140202_N    float64
# 20140117_N    float64
# 20140101_N    float64
# dtype: object

# %%
sns.heatmap(df1.drop(['class'], axis = 1).corr())
# Out:
# <Axes: >

# %%
## Using profilereporting module for EDA part.
! pip install ydata-profiling
from ydata_profiling import ProfileReport
prof = ProfileReport(df1)
prof.to_file(output_file='output.html')
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 14.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 29.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 47.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 120.2 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=bf97a697bff8942ffc07a9741e1cdbc950c53aba52b374dc21cd7f2b94bf2730
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
# ...

# %%
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer()
X_train_pt = pt.fit_transform(X_train)
X_test_pt = pt.transform(df)

# %%
df1.fillna(df1.mean(numeric_only=True), inplace=True) #simple mean imputation [This part has a lot of scope for imporovement.]
#keep in mind that the data is inherently noisy and the test dataset is not.
df1.isnull().sum()
# Out:
# Unnamed: 0    0
# ID            0
# class         0
# 20150720_N    0
# 20150602_N    0
# 20150517_N    0
# 20150501_N    0
# 20150415_N    0
# 20150330_N    0
# 20150314_N    0
# 20150226_N    0
# 20150210_N    0
# 20150125_N    0
# 20150109_N    0
# 20141117_N    0
# 20141101_N    0
# 20141016_N    0
# 20140930_N    0
# 20140813_N    0
# 20140626_N    0
# 20140610_N    0
# 20140525_N    0
# 20140509_N    0
# 20140423_N    0
# 20140407_N    0
# 20140322_N    0
# 20140218_N    0
# 20140202_N    0
# 20140117_N    0
# 20140101_N    0
# dtype: int64

# %%
X = df1.drop(['class'],axis = 1)
y = df1['class']

# %%
X.columns
# Out:
# Index(['Unnamed: 0', 'ID', '20150720_N', '20150602_N', '20150517_N',
#        '20150501_N', '20150415_N', '20150330_N', '20150314_N', '20150226_N',
#        '20150210_N', '20150125_N', '20150109_N', '20141117_N', '20141101_N',
#        '20141016_N', '20140930_N', '20140813_N', '20140626_N', '20140610_N',
#        '20140525_N', '20140509_N', '20140423_N', '20140407_N', '20140322_N',
#        '20140218_N', '20140202_N', '20140117_N', '20140101_N'],
#       dtype='object')

# %%
y.unique()
# Out:
# array(['water', 'forest', 'impervious', 'farm', 'grass', 'orchard'],
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5360 entries, 1194 to 7270
# Data columns (total 29 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5360 non-null   int64
#  1   ID          5360 non-null   int64
#  2   20150720_N  5360 non-null   float64
#  3   20150602_N  5360 non-null   float64
#  4   20150517_N  5360 non-null   float64
#  5   20150501_N  5360 non-null   float64
#  6   20150415_N  5360 non-null   float64
#  7   20150330_N  5360 non-null   float64
#  8   20150314_N  5360 non-null   float64
#  9   20150226_N  5360 non-null   float64
#  10  20150210_N  5360 non-null   float64
#  11  20150125_N  5360 non-null   float64
#  12  20150109_N  5360 non-null   float64
#  13  20141117_N  5360 non-null   float64
#  14  20141101_N  5360 non-null   float64
#  15  20141016_N  5360 non-null   float64
#  16  20140930_N  5360 non-null   float64
#  17  20140813_N  5360 non-null   float64
# ...

# %%
## Import function transformer module as most of data is skewed
from sklearn.compose import ColumnTransformer

# %%
trf = FunctionTransformer(func = np.log1p)

# %%
## removing skewness of data
X_train_transformed = trf.fit_transform(X_train)
X_test_transfored = trf.transform(X_test)

# %%
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer()
X_train_pt = pt.fit_transform(X_train)
X_test_pt = pt.transform(X_test)

# %%
! pip install ydata-profiling
from ydata_profiling import ProfileReport
prof = ProfileReport(X_train_transformed)
prof.to_file(output_file='output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10,4))
plt.subplot(121)
sns.distplot(X_train['20150415_N'])
plt.title('20150415_N')

plt.subplot(122)
sns.distplot(X_train_transformed['20150415_N'])
plt.title('20150415_N')
# Out:
# Text(0.5, 1.0, '20150415_N')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaler = scaler.fit_transform(X_train)
X_test_scaler =scaler.transform(X_train)

# %%
# Installing Machine models which could perform well over the same classifier data.
from sklearn.linear_model import LogisticRegressionCV
# !pip install Xgboost
import xgboost as xb
from xgboost import XGBClassifier

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
log = LogisticRegressionCV()
model = log.fit(X_train_scaler,y_train)
y_pred = log.predict(X_test_scaler)

# %%
## checking the accouracy with cross validation technique
np.mean(cross_val_score(log,X_train_scaler,y_train,scoring = 'accuracy',cv = 5))
# Out:
# 0.9613805970149254

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[ 230    5    5   29    2    0]
#  [   4 2032    0    1    0    3]
#  [   8    0   52    7    0    0]
#  [  20    6    6  184    1    0]
#  [   4    0    1    1    4    0]
#  [   0    8    0    1    0   26]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         farm       0.86      0.85      0.86       271
#       forest       0.99      1.00      0.99      2040
#        grass       0.81      0.78      0.79        67
#   impervious       0.83      0.85      0.84       217
#      orchard       0.57      0.40      0.47        10
#        water       0.90      0.74      0.81        35
#
#     accuracy                           0.96      2640
#    macro avg       0.83      0.77      0.79      2640
# weighted avg       0.96      0.96      0.96      2640

# %%
X_test_scaler = scaler.transform(X_test)
y_test_reset = y_test.reset_index(drop=True)

# Now predict using the correctly scaled test data
y_pred = log.predict(X_test_scaler)

# Calculate confusion matrix using the reset y_test index
print(confusion_matrix(y_test_reset, y_pred))
# Out:
# [[ 230    5    5   29    2    0]
#  [   4 2032    0    1    0    3]
#  [   8    0   52    7    0    0]
#  [  20    6    6  184    1    0]
#  [   4    0    1    1    4    0]
#  [   0    8    0    1    0   26]]

# %%
## importing test data
df=pd.read_csv('/content/hacktest.csv')
df
# Out:
#       Unnamed: 0    ID  20150720_N  20150602_N  20150517_N  20150501_N  \
# 0              0     1   7466.4200     413.162    5761.000     5625.45
# 1              1     2   7235.2600    6037.350    1027.560     6085.14
# 2              2     3   7425.0800    6969.980    1177.940     7408.93
# 3              3     4   7119.1200    1731.620    6311.930     6441.61
# 4              4     5   7519.5500    8130.260    1482.540     7879.53
# ...          ...   ...         ...         ...         ...         ...
# 2840        2840  2841  -1673.7400   -2514.480   -2451.190    -2738.44
# 2841        2841  2842    -96.8233    -412.727   -1795.400    -2363.82
# 2842        2842  2843  -2364.6000    -155.592   -1422.090    -1713.40
# 2843        2843  2844  -3004.6300   -1217.120     180.122    -1113.89
# 2844        2844  2845  -2975.1000   -1129.790     463.748    -5355.40
#
#       20150415_N  20150330_N  20150314_N  20150226_N  ...  20140610_N  \
# ...

# %%
df1.fillna(df1.mean(numeric_only=True), inplace=True) #simple mean imputation [This part has a lot of scope for imporovement.]
#keep in mind that the data is inherently noisy and the test dataset is not.
df1.isnull().sum()
# Out:
# Unnamed: 0    0
# ID            0
# class         0
# 20150720_N    0
# 20150602_N    0
# 20150517_N    0
# 20150501_N    0
# 20150415_N    0
# 20150330_N    0
# 20150314_N    0
# 20150226_N    0
# 20150210_N    0
# 20150125_N    0
# 20150109_N    0
# 20141117_N    0
# 20141101_N    0
# 20141016_N    0
# 20140930_N    0
# 20140813_N    0
# 20140626_N    0
# 20140610_N    0
# 20140525_N    0
# 20140509_N    0
# 20140423_N    0
# 20140407_N    0
# 20140322_N    0
# 20140218_N    0
# 20140202_N    0
# 20140117_N    0
# 20140101_N    0
# dtype: int64

# %%
X_test_transfored = trf.transform(df)

# %%
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer()
X_train_pt = pt.fit_transform(X_train)
X_test_pt = pt.transform(df)

# %%
#standardising the test data for get more accouracy in modol, we can set a pipe line for this

# %%
test_scaler =scaler.transform(df)

# %%
# predicting the test data now
y_pred_test = log.predict(test_scaler)

# %%
y_pred
# Out:
# array(['forest', 'forest', 'forest', ..., 'impervious', 'farm', 'forest'],
#       dtype=object)

# %%
y_pred
# Out:
# array(['forest', 'forest', 'forest', ..., 'impervious', 'farm', 'forest'],
#       dtype=object)

# %%
y_pred_test
# Out:
# array(['forest', 'forest', 'forest', ..., 'water', 'water', 'water'],
#       dtype=object)

# %%
ID=df['ID']
result = pd.DataFrame({
    'ID': ID,
    'class': y_pred_test
})

# %%
result.value_counts()
# Out:
# ID    class
# 2845  water     1
# 1     forest    1
# 2     forest    1
# 3     forest    1
# 4     forest    1
#                ..
# 33    water     1
# 34    forest    1
# 35    water     1
# 36    water     1
# 37    water     1
# Name: count, Length: 2845, dtype: int64

# %%
result.to_csv("submission.csv", index=False) #this file will appear under the output section of the right navbar. You need to submit this csv file

# %%
# prompt: please prive a summerized note for above code and explain the steps

# The code performs the following steps:
# 1. Imports necessary libraries for data manipulation, visualization, and machine learning.
# 2. Reads the training data ('hacktrain.csv') into a pandas DataFrame.
# 3. Performs basic data exploration: checking columns, null values, duplicates, and data types.
# 4. Visualizes the correlation matrix of the training data (excluding the target variable).
# 5. Generates an extensive EDA report using ydata-profiling and saves it as an HTML file.
# 6. Imputes missing values in the training data using the mean (notes potential for improvement).
# 7. Separates features (X) and the target variable (y).
# 8. Splits the training data into training and validation sets.
# 9. Applies a logarithmic transformation (using FunctionTransformer) to the training and validation feature sets to handle skewness.
# 10. Also applies a PowerTransformer to the training and validation feature sets.
# 11. Generates a ydata-profiling report for the transformed training data.
# 12. Visualizes the distribution of a specific feature before and after the logarithmic transformation.
# 13. Standardizes the training and validation feature sets using StandardScaler.
# 14. Trains a Logistic Regression model with cross-validation on the standardized training data.
# 15. Predicts on the standardized validation set and evaluates the model's performance using accuracy, confusion matrix, and classification report.
# 16. Reads the test data ('hacktest.csv') into a pandas DataFrame.
# 17. Imputes missing values in the test data using the mean (notes potential for improvement and data noise).
# 18. Applies the previously fitted logarithmic and PowerTransformer transformations to the test data.
# 19. Standardizes the test data using the previously fitted StandardScaler.
# 20. Predicts the target variable for the test data using the trained Logistic Regression model.
# 21. Creates a submission DataFrame with 'ID' and the predicted 'class' for the test data.
# 22. Saves the submission DataFrame to a CSV file named 'submission.csv'.
